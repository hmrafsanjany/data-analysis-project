# %%
def get_expected_cost(beds, baths):
    base_cost = 80000
    total_cost = base_cost + (beds * 30000) + (baths * 10000)
    return total_cost

print(get_expected_cost(1, 1))
print(get_expected_cost(2, 1))
# Out:
# 120000
# 150000

# %%
for number in range(100, 1001):
      print(number)
# Out:
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# ...

# %%
def check_even_or_odd(number):
     if number % 2 == 0:
      print(f"{number} is even.")
       else:
      print(f"{number} is odd.")
# Out:
#   File "<ipython-input-4-29e67934f6d9>", line 4
#     else:
#     ^
# IndentationError: unexpected indent

# %%
def check_even_odd(number):
    if number % 2 == 0:
        print(f"{number} is even")
    else:
        print(f"{number} is odd")

# %%
days = "Saturday Sunday Monday Tuesday Thursday Friday"
days_list = days.split()
 print(days_list)
# Out:
#   File "<ipython-input-6-08920bbdab6e>", line 3
#     print(days_list)
#     ^
# IndentationError: unexpected indent

# %%
days = "Saturday Sunday Monday Tuesday Thursday Friday"
days_list = days.split()
print(days_list)
# Out:
# ['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Thursday', 'Friday']

# %%
import pandas as pf
import numpy as np
nfl_data= pd.read("/content/NFL Play by Play 2009-2017 (v4).csv.zip")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cf6709cbfce3> in <cell line: 3>()
#       1 import pandas as pf
#       2 import numpy as np
# ----> 3 nfl_data= pd.read("/content/NFL Play by Play 2009-2017 (v4).csv.zip")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
nfl_data=pd.read_csv("/content/drive/MyDrive/NFL Play by Play 2009-2017 (v4).csv")
# Out:
# <ipython-input-33-4e03fae437cd>:3: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   nfl_data=pd.read_csv("/content/drive/MyDrive/NFL Play by Play 2009-2017 (v4).csv")

# %%
nfl_data.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
missing_values_count = nfl_data.isnull().sum()
print(missing_values_count)
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         61154
#              ...
# Win_Prob     25009
# WPA           5541
# airWPA      248501
# yacWPA      248762
# Season           0
# Length: 102, dtype: int64

# %%
total_cells = np.product(nfl_data.shape)
total_missing = missing_values_count.sum()
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 27.66722370547874

# %%
missing_values_count
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         61154
#              ...
# Win_Prob     25009
# WPA           5541
# airWPA      248501
# yacWPA      248762
# Season           0
# Length: 102, dtype: int64

# %%
nfl_data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
column_with_na_dropped = nfl_data.dropna(axis=1)
column_with_na_dropped.head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp  ...  AwayTeam  Timeout_Indicator  \
# 0              1            39   0  ...       TEN                  0
# 1              1             5   0  ...       TEN                  0
# 2              1            -3   0  ...       TEN                  0
# 3              1             0   0  ...       TEN                  0
# 4              1             0   0  ...       TEN                  0
#
#    posteam_timeouts_pre HomeTimeouts_Remaining_Pre  \
# 0                     3                          3
# ...

# %%
print("columns in original database :%d/n", nfl_data.shape[1])
print("columns with na's dropped: %d/n", column_with_na_dropped.shape[1])
# Out:
# columns in original database :%d/n 102
# columns with na's dropped: %d/n 37

# %%
subset_nfl_data = nfl_data.loc[:, "EPA":"Season"].head()
subset_nfl_data
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %%
subset_nfl_data.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
subset_nfl_data.fillna(method='bfill', axis=0).fillna(0)
# Out:
# <ipython-input-43-b29688b3d9c8>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   subset_nfl_data.fillna(method='bfill', axis=0).fillna(0)
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239    2009
# ...

# %%
import pandas as pd
import numpy as np
permit=pd.read_csv("/content/drive/MyDrive/Building_Permits.csv.zip")
# Out:
# <ipython-input-49-d9836ce2d259>:3: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   permit=pd.read_csv("/content/drive/MyDrive/Building_Permits.csv.zip")

# %%
missing_values_count = permit.isnull().sum()
print(missing_values_count)
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
total_cells = np.product(permit.shape)
total_missing = missing_values_count.sum()
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 26.26002315058403

# %%
missing_values_count=permit.isnull().sum()
total_values=np.product(permit.shape)
missing_percent=(missing_values_count/total_values)*100
print(missing_percent)
# Out:
# Permit Number                             0.000000
# Permit Type                               0.000000
# Permit Type Definition                    0.000000
# Permit Creation Date                      0.000000
# Block                                     0.000000
# Lot                                       0.000000
# Street Number                             0.000000
# Street Number Suffix                      2.299671
# Street Name                               0.000000
# Street Suffix                             0.032364
# Unit                                      1.980907
# Unit Suffix                               2.302653
# Description                               0.003391
# Current Status                            0.000000
# Current Status Date                       0.000000
# Filed Date                                0.000000
# Issued Date                               0.174682
# Completed Date                            1.189203
# ...

# %%
subset_data = permit.loc[:, "Street Number Suffix":"Zipcode"].head()
subset_data
# Out:
#   Street Number Suffix Street Name Street Suffix  Unit Unit Suffix  \
# 0                  NaN       Ellis            St   NaN         NaN
# 1                  NaN       Geary            St   0.0         NaN
# 2                  NaN     Pacific            Av   NaN         NaN
# 3                  NaN     Pacific            Av   0.0         NaN
# 4                  NaN      Market            St   NaN         NaN
#
#                                          Description Current Status  \
# 0  ground fl facade: to erect illuminated, electr...        expired
# 1            remove (e) awning and associated signs.         issued
# 2                    installation of separating wall      withdrawn
# 3           repair dryrot & stucco at front of bldg.       complete
# 4  demolish retail/office/commercial 3-story buil...         issued
#
#   Current Status Date  Filed Date Issued Date  ... Plansets TIDF Compliance  \
# ...

# %% [markdown]
# 5 exercise

# %%
permit_with_na_dropped = permit.dropna(axis=1, how='all')


dropped_columns = permit.shape[1] - permit_with_na_dropped.shape[1]

# %% [markdown]
# 6

# %%
permit_with_na_imputed = permit.fillna(method='ffill').fillna(0)
# Out:
# <ipython-input-59-7ef4d3235f82>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   permit_with_na_imputed = permit.fillna(method='ffill').fillna(0)

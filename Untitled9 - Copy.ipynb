# %%
planets = ['mercury', 'venus', 'mars']

# %%
planets= ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
for planet in planets:
    print(planet)
# Out:
# Mercury
# Venus
# Earth
# Mars
# Jupiter
# Saturn
# Uranus
# Neptune

# %%
planets= ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
for planet in planets:
    print(planet)
# Out:
# Mercury
# Venus
# Earth
# Mars
# Jupiter
# Saturn
# Uranus
# Neptune

# %%
s= 'steganography is the practice of concealinga file '
for chr in s:
  print(chr)
# Out:
# s
# t
# e
# g
# a
# n
# o
# g
# r
# a
# p
# h
# y
#
# i
# s
#
# t
# h
# e
#
# p
# r
# a
# c
# t
# i
# c
# e
#
# o
# f
#
# c
# o
# n
# c
# e
# a
# l
# i
# n
# g
# a
#
# f
# i
# l
# e

# %%
letter ='a'
print(letter.isupper())
letter= 'A'
print(letter.isupper())
# Out:
# False
# True

# %%
s= 'steganography is the practIce of conceaLinga fiLe, Image , gaNdu ,NaNdu  '
for chr in s:
  if chr.isupper():
    print(chr)
# Out:
# I
# L
# L
# I
# N
# N
# N

# %%
for i in range(10):
  print("doing important work",i)
# Out:
# doing important work 0
# doing important work 1
# doing important work 2
# doing important work 3
# doing important work 4
# doing important work 5
# doing important work 6
# doing important work 7
# doing important work 8
# doing important work 9

# %%
i=0
while i < 5:
      print(i)
      i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# list comprehention

# %%
squares = [n**2 for n in range(10)]
print (squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = []
for n in range(10):
  squares.append(n**2)
  #squares # Removed the extra space before print statement to align with the for loop
print(squares)
  squares # Removed the extra space before print statement to align with the for loop
# Out:
#   File "<ipython-input-28-6ee9152d58bd>", line 6
#     squares # Removed the extra space before print statement to align with the for loop
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# **`string`**

# %%
x='Pluto is a planet'
y="Pluto is a star"
x==y
# Out:
# False

# %%
'pluto\'s a planet!'
# Out:
# "pluto's a planet!"

# %%
a= """hello\n
world"""
print(a)
# Out:
# hello
#
# world

# %%
print("hello")
print("world")
print("hello",end='')
print("pluto",end='')
# Out:
# hello
# world
# hellopluto

# %%
planet='plutos'
planet[0]
# Out:
# 'p'

# %%
planet[-2:]
# Out:
# 'to'

# %%
len(planet)
# Out:
# 6

# %%
my_list=[10,20,30]
print (my_list)
# Out:
# [10, 20, 30]

# %%
len(my_list)
# Out:
# 3

# %%
claim="pluto is a planet"
claim.upper()
# Out:
# 'PLUTO IS A PLANET'

# %%
claim="PLUTO IS A PLANET"
claim.lower()
# Out:
# 'pluto is a planet'

# %%
claim.index('pla')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-9f42672ccc3a> in <cell line: 1>()
# ----> 1 claim.index('pla')
#
# ValueError: substring not found

# %%
claim.index('PAL')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-b3da1ae42d16> in <cell line: 1>()
# ----> 1 claim.index('PAL')
#
# ValueError: substring not found

# %% [markdown]
# split

# %%
word=claim.split()
word
# Out:
# ['PLUTO', 'IS', 'A', 'PLANET']

# %%
datestr='1956-01-31'
year,month,day=datestr.split('-')
print(year,month,day)
# Out:
# 1956 01 31

# %%
mystr='//'.join([year,month,day])
print(mystr)
# Out:
# 1956//01//31

# %%
divider='+'
sesson= '16'
semester='02'
department='CSE'
bday='21'
print(divider.join([department,semester,bday, sesson]))
# Out:
# CSE+02+21+16

# %% [markdown]
# DICTIONARY

# %%
numbers={'one':1,'two':2,'three':3}

# %%
numbers['two']
# Out:
# 2

# %%
print('one' in numbers)
print('ten' in numbers)
# Out:
# True
# False

# %%
numbers= {'pluto':1,'ten':2,'tree':3}
print (numbers.keys())
print (numbers.values())
# Out:
# dict_keys(['pluto', 'ten', 'tree'])
# dict_values([1, 2, 3])

# %%
for k in numbers:
  print(f"{k}={numbers[k]}")
# Out:
# pluto=1
# ten=2
# tree=3

# %%
import math
print ("number",math.pi)
# Out:
# number 3.141592653589793
